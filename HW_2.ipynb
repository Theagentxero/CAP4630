# %% [markdown]
# <a href="https://colab.research.google.com/github/Theagentxero/CAP4630/blob/master/HW_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# HW 2 - Taylor Richards
#
# # Problem 1

# %%
from mpl_toolkits import mplot3d
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

# %% [markdown]
# ### F1
# $ z = \sqrt{x} + \sqrt{y} $

# %%
def f1(x, y):
    return np.sqrt(x) + np.sqrt(y)

x = np.linspace(0, 1, 150)
y = np.linspace(0, 1, 150)

X, Y = np.meshgrid(x, y)
Z = f1(X, Y)

fig = plt.figure()
ax = plt.axes(projection='3d')
#ax.contour3D(X, Y, Z, 50, rstride=1, cmap='viridis')
ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap='viridis', edgecolor='none')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z');
ax.scatter(0, 0, 0, color='green')
ax.text(0.1, 0, 0, "Minima", color='green')
# Out:
# Text(0.1, 0, 'Minima')

# %% [markdown]
# ### F2
# $ z = \sin{x} + \sin{y} $

# %%
def f2(x, y):
    return np.sin(x) + np.sin(y)

x = np.linspace(-np.pi /2, np.pi + np.pi/2, 150)
y = np.linspace(-np.pi /2, np.pi + np.pi/2, 150)

X, Y = np.meshgrid(x, y)
Z = f2(X, Y)

fig = plt.figure()
ax = plt.axes(projection='3d')
#ax.contour3D(X, Y, Z, 50, rstride=1, cmap='viridis')
ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap='viridis', edgecolor='none')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z');
ax.scatter(np.pi/2, np.pi/2, 2+0.1, color='red')
ax.text(np.pi/2 + 0.1,np.pi/2, 2+0.1, "maxima", color='red')
# Out:
# Text(1.6707963267948966, 1.5707963267948966, 'maxima')

# %% [markdown]
# ### F3
# $ z = x^2 + y^2 $

# %%
def f2(x, y):
    return x**2 - y**2

x = np.linspace(-1, 1, 150)
y = np.linspace(-1, 1, 150)

X, Y = np.meshgrid(x, y)
Z = f2(X, Y)

fig = plt.figure()
ax = plt.axes(projection='3d')
#ax.contour3D(X, Y, Z, 50, rstride=1, cmap='viridis')
ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap='viridis', edgecolor='none')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z');
ax.scatter(0,0,0, color='yellow')
ax.text(0.2,0,0.1, "zero vector", color='yellow')
# Out:
# Text(0.2, 0, 'zero vector')

# %% [markdown]
# # Problem 2

# %%
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

# generate m random pairs (x, y)

m = 100
X = 2 * np.random.rand(m, 1)
X_2 = 3 * np.random.rand(m, 1)
y = 4 + 3 * X + np.random.rand(m, 1)

# %%
# number of epochs
epochs = 20
# learning rate
lr = 0.01
# fix initial random weight for gradient descent (batch gradient descent)
np.random.seed(42)
initial_weight = np.random.randn(3, 1)

# %%
# add x0 = 1 
X_b = np.column_stack([np.ones((m, 1)), X, X_2])

# %%
weight = initial_weight
weight_path_mgd = []
batch_size = 4

weight_path_mgd.append(weight)
for epoch in range(epochs):
    shuffled_indices = np.random.permutation(m)
    X_b_shuffled = X_b[shuffled_indices]
    y_shuffled = y[shuffled_indices]
    for i in range(0, m, batch_size):
        xi = X_b_shuffled[i:i+batch_size]
        yi = y_shuffled[i:i+batch_size]
        intermediate = xi.dot(weight) - yi;
        gradient = 1 / batch_size * xi.T.dot(intermediate)
        weight = weight - lr * gradient
        weight_path_mgd.append(weight)

# %%
# weight_path_mgd = np.array(weight_path_mgd)
# plt.figure(figsize=(12,12))
# plt.plot(weight_path_mgd[:, 0], weight_path_mgd[:, 1], "g-s", linewidth=2, label="mini-batch")
# plt.legend(loc="upper left", fontsize=16)
# plt.xlabel(r"$w_0$", fontsize=20)
# plt.ylabel(r"$w_1$   ", fontsize=20, rotation=0)
# plt.axis([-1, 5, -1, 4])
# plt.show()

fig = plt.figure(figsize=(12,12))
ax = plt.axes(projection='3d')
ax.scatter(weight_path_mgd[:, 0], weight_path_mgd[:, 1], weight_path_mgd[:, 2])

# %% [markdown]
# # Problem 3

# %%
# %tensorflow_version 2.x
import tensorflow as tf

(train_images, train_labels), (test_images, test_labels) = tf.keras.datasets.mnist.load_data()
total = 0
cnt0 = 0
cnt1 = 0
cnt2 = 0
cnt3 = 0
cnt4 = 0
cnt5 = 0
cnt6 = 0
cnt7 = 0
cnt8 = 0
cnt9 = 0
for i in train_labels:
    total = total + i
    if(i == 0):
        cnt0 = cnt0 + 1
    if(i == 1):
        cnt1 = cnt1 + 1
    if(i == 2):
        cnt2 = cnt2 + 1
    if(i == 3):
        cnt3 = cnt3 + 1
    if(i == 4):
        cnt4 = cnt4 + 1
    if(i == 5):
        cnt5 = cnt5 + 1
    if(i == 6):
        cnt6 = cnt6 + 1
    if(i == 7):
        cnt7 = cnt7 + 1
    if(i == 8):
        cnt8 = cnt8 + 1
    if(i == 9):
        cnt9 = cnt9 + 1

res = total / len(train_labels)

print("Set Average:")
print(res)

print("Probabilities:")
print("0: Occurs: " + str(cnt0) + " Times " + str( (cnt0/len(train_labels))*100 ) + "%" )
print("1: Occurs: " + str(cnt1) + " Times " + str( (cnt1/len(train_labels))*100 ) + "%" )
print("2: Occurs: " + str(cnt2) + " Times " + str( (cnt2/len(train_labels))*100 ) + "%" )
print("3: Occurs: " + str(cnt3) + " Times " + str( (cnt3/len(train_labels))*100 ) + "%" )
print("4: Occurs: " + str(cnt4) + " Times " + str( (cnt4/len(train_labels))*100 ) + "%" )
print("5: Occurs: " + str(cnt5) + " Times " + str( (cnt5/len(train_labels))*100 ) + "%" )
print("6: Occurs: " + str(cnt6) + " Times " + str( (cnt6/len(train_labels))*100 ) + "%" )
print("7: Occurs: " + str(cnt7) + " Times " + str( (cnt7/len(train_labels))*100 ) + "%" )
print("8: Occurs: " + str(cnt8) + " Times " + str( (cnt8/len(train_labels))*100 ) + "%" )
print("9: Occurs: " + str(cnt9) + " Times " + str( (cnt9/len(train_labels))*100 ) + "%" )
# Out:
# Set Average:
# 4.4539333333333335
# Probabilities:
# 0: Occurs: 5923 Times 9.871666666666666%
# 1: Occurs: 6742 Times 11.236666666666666%
# 2: Occurs: 5958 Times 9.93%
# 3: Occurs: 6131 Times 10.218333333333334%
# 4: Occurs: 5842 Times 9.736666666666666%
# 5: Occurs: 5421 Times 9.035%
# 6: Occurs: 5918 Times 9.863333333333333%
# 7: Occurs: 6265 Times 10.441666666666666%
# 8: Occurs: 5851 Times 9.751666666666667%
# 9: Occurs: 5949 Times 9.915000000000001%
